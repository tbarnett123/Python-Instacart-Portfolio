# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
y = 5.678

# %%
type (y)
# Out:
# float

# %%
z = 'Brazil'

# %%
type(z)
# Out:
# str

# %%
type ('Mania')
# Out:
# str

# %%
type (True)
# Out:
# bool

# %%
type (False)
# Out:
# bool

# %%
x = 2

# %%
print(x)
# Out:
# 2

# %%
x + 4
# Out:
# 6

# %%
x+y
# Out:
# 7.678

# %%
x = x + 4

# %%
print(x)
# Out:
# 10

# %%
a = 'Hello, '

# %%
b = 'Marley'

# %%
a +b
# Out:
# 'Hello,Marley'

# %%
n = 'potato'

# %%
n * 12
# Out:
# 'potatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotato'

# %%
x==y
# Out:
# False

# %%
type(x == y)
# Out:
# bool

# %%
a = 50

# %%
b = 50

# %%
a + b
# Out:
# 100

# %%
b + 50
# Out:
# 100

# %%
c = 150

# %%
c - a
# Out:
# 100

# %%
p = 57.10

# %%
r = 9785.447

# %%
r/p
# Out:
# 171.37385288966726

# %%
u = 'Avada '

# %%
t = 'Kedavra'

# %%
u + t
# Out:
# 'Avada Kedavra'

# %%
d = 'RONALD WESLEY. How DARE you steal that car!'

# %%
e = ' I am ABSOLUTELY DISGUSTED.'

# %%
d + e
# Out:
# 'RONALD WESLEY. How DARE you steal that car! I am ABSOLUTELY DISGUSTED.'
