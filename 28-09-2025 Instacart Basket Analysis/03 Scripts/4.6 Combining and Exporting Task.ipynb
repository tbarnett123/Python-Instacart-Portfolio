# %% [markdown]
# Tasks for 4.6

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
#creating a path
path = r'/Users/tiffanib./Desktop/Career Foundry Data Analytics/Achievement 4 - Python/28-09-2025 Instacart Basket Analysis'

# %%
path
# Out:
# '/Users/tiffanib./Desktop/Career Foundry Data Analytics/Achievement 4 - Python/28-09-2025 Instacart Basket Analysis'

# %% [markdown]
# Number 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data','Prepared Data','product_cleaned.csv'), index_col = 0)

# %% [markdown]
# Number 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
#checking the shape of the imported dataframe
orders_products_combined.shape
# Out:
# (32434489, 12)

# %% [markdown]
# Number 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
#checking the dataframe structure 
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  orders_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                   8                     NaN         196
# 1                   2                   8                     NaN       14084
# 2                   2                   8                     NaN       12427
# 3                   2                   8                     NaN       26088
# 4                   2                   8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
#checking the shape
df_prods.shape
# Out:
# (49672, 5)

# %%
#checking the structure of the products df
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#merge of orders_products_combined and df_prods
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'], indicator = 'match')

# %% [markdown]
# Number 6. Confirm the results of the merge using the merge flag.

# %%
#dropping the flag column 'merge' from the previous merge
ords_prods_merge.drop('_merge',axis =1)
# Out:
#           Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0                    0           0   2539329        1             1
# 1                    0           0   2539329        1             1
# 2                    0           0   2539329        1             1
# 3                    0           0   2539329        1             1
# 4                    0           0   2539329        1             1
# ...                ...         ...       ...      ...           ...
# 32404854       3421081     3421081   2977660   206209            13
# 32404855       3421081     3421081   2977660   206209            13
# 32404856       3421081     3421081   2977660   206209            13
# 32404857       3421081     3421081   2977660   206209            13
# 32404858       3421081     3421081   2977660   206209            13
#
#           orders_day_of_week  orders_hour_of_day  days_since_prior_order  \
# 0                          2                   8                     NaN
# ...

# %%
#checking the output
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id  order_number  \
# 0             0           0   2539329        1             1
# 1             0           0   2539329        1             1
# 2             0           0   2539329        1             1
# 3             0           0   2539329        1             1
# 4             0           0   2539329        1             1
#
#    orders_day_of_week  orders_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                   8                     NaN         196
# 1                   2                   8                     NaN       14084
# 2                   2                   8                     NaN       12427
# 3                   2                   8                     NaN       26088
# 4                   2                   8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %%
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#exporting data to pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
