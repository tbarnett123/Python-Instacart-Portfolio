# %%
#Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
#Created a string for project folder
df = pd.read_csv(r'/Users/tiffanib./Desktop/Career Foundry Data Analytics/Achievement 4 - Python/28-09-2025 Instacart Basket Analysis/02 Data/Original Data/orders.csv',index_col = False)

# %%
path = r'/Users/tiffanib./Desktop/Career Foundry Data Analytics/Achievement 4 - Python/28-09-2025 Instacart Basket Analysis'

# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
#Imported Orders.csv
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
#Created Vars List Excluding "Eval_set"
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), usecols = vars_list)

# %%
#Printed the 1st 5 rows of the dataframe
df.head()

# %%
#Importing 'products.csv' file
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
#Printing the 1st 20 rows and the last 35 of df_prods dataframe
df_prods.head(20)

# %%
#Using tail() to find the last 35 rows
df_prods.tail(35)

# %%
#Printing the name of the columns in the df_prods dataframe
df_prods.columns

# %%
#Using describe function to find the maximum value of the aisle_id column
df_prods.describe()

# %%
#Maximum for aisle_id is 134.000

# %%
#Using dtypes to define the column data types
df_prods.dtypes

# %%
#dtype of department_id is int64
